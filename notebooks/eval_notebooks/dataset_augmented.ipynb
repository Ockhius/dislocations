# %%
config_file = 'delineation/configs/dislocation_matching_disp_and_warp_and var_joint_home.yml'
aug_config_file = 'delineation/configs/aug.yml'
import torch
from delineation.configs.defaults_segmentation import _C as cfg
from delineation.datasets import make_data_loader
# %matplotlib inline
import matplotlib.pyplot as plt

import yaml

cfg.merge_from_file(config_file)
with open(aug_config_file, 'r') as ymlfile:
    cfg_aug = yaml.load(ymlfile)

# %%
train_loader, val_loader = make_data_loader(cfg, cfg_aug)

# %%
l_aug, r_aug, l_gt_aug, r_gt_aug, l, r, lgt, rgt, dlgt, l_name = train_loader.dataset[2]
print(l_name)
# Out:
# 1114_1114 DPC DF4 71.0 kx DF4-B_LEFT.png

# %%
plt.figure(figsize = (10,10))
plt.imshow(l[0], cmap='gray')

# %%
plt.figure(figsize = (10,10))
plt.imshow(l_aug[0], cmap='gray')

# %%
plt.figure(figsize = (10,10))
plt.imshow(l_gt_aug[0], cmap='gray')

# %%
plt.figure(figsize = (10,10))
plt.imshow(r[0], cmap='gray')

# %%
plt.figure(figsize = (10,10))

plt.imshow(dlgt, cmap='gray')
print(dlgt.min())
print(dlgt.max())
# Out:
# 4.0
# 10.0
